# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)
df=pd.read_csv('Pokemon.csv')

# %%
#df=poke.head(166)
df = df[df['Generation'] < 2] #Taking only the original generation of pokemons

# %%
df
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur    Grass    Poison    318   45      49
# 1      2                Ivysaur    Grass    Poison    405   60      62
# 2      3               Venusaur    Grass    Poison    525   80      82
# 3      3  VenusaurMega Venusaur    Grass    Poison    625   80     100
# 4      4             Charmander     Fire       NaN    309   39      52
# ..   ...                    ...      ...       ...    ...  ...     ...
# 161  149              Dragonite   Dragon    Flying    600   91     134
# 162  150                 Mewtwo  Psychic       NaN    680  106     110
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 165  151                    Mew  Psychic       NaN    600  100     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df=df.drop(["Generation"], axis=1) #Dropping the column which I don't find useful

# %%
df
# Out:
#        #                   Name   Type 1    Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur    Grass    Poison    318   45      49
# 1      2                Ivysaur    Grass    Poison    405   60      62
# 2      3               Venusaur    Grass    Poison    525   80      82
# 3      3  VenusaurMega Venusaur    Grass    Poison    625   80     100
# 4      4             Charmander     Fire       NaN    309   39      52
# ..   ...                    ...      ...       ...    ...  ...     ...
# 161  149              Dragonite   Dragon    Flying    600   91     134
# 162  150                 Mewtwo  Psychic       NaN    680  106     110
# 163  150    MewtwoMega Mewtwo X  Psychic  Fighting    780  106     190
# 164  150    MewtwoMega Mewtwo Y  Psychic       NaN    780  106     150
# 165  151                    Mew  Psychic       NaN    600  100     100
#
#      Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 0         49       65       65     45      False
# ...

# %%
df=df.dropna() #dropping the pokemons with no Type2/NaN

# %%
df
# Out:
#        #                   Name    Type 1    Type 2  Total   HP  Attack  \
# 0      1              Bulbasaur     Grass    Poison    318   45      49
# 1      2                Ivysaur     Grass    Poison    405   60      62
# 2      3               Venusaur     Grass    Poison    525   80      82
# 3      3  VenusaurMega Venusaur     Grass    Poison    625   80     100
# 6      6              Charizard      Fire    Flying    534   78      84
# ..   ...                    ...       ...       ...    ...  ...     ...
# 156  144               Articuno       Ice    Flying    580   90      85
# 157  145                 Zapdos  Electric    Flying    580   90      90
# 158  146                Moltres      Fire    Flying    580   90     100
# 161  149              Dragonite    Dragon    Flying    600   91     134
# 163  150    MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
#
#      Defense  Sp. Atk  Sp. Def  Speed  Legendary
# 0         49       65       65     45      False
# ...

# %%
df=df.loc[df['Type 1'] == "Water"] #Interested only in watertypes

# %%
df=df.sort_values(by="Total",ascending=False) #Finding out which pokemon has the strongest Total

# %%
df
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 141  130  GyaradosMega Gyarados  Water      Dark    640   95     155      109
# 87    80    SlowbroMega Slowbro  Water   Psychic    590   95      75      180
# 140  130               Gyarados  Water    Flying    540   95     125       79
# 142  131                 Lapras  Water       Ice    535  130      85       80
# 98    91               Cloyster  Water       Ice    525   50      95      180
# 130  121                Starmie  Water   Psychic    520   60      75       85
# 79    73             Tentacruel  Water    Poison    515   80      70       65
# 67    62              Poliwrath  Water  Fighting    510   90      95       95
# 86    80                Slowbro  Water   Psychic    490   95      75      110
# 94    87                Dewgong  Water       Ice    475   90      70       80
# 78    72              Tentacool  Water    Poison    335   40      40       35
# ...

# %%
df1=df #Making a new variable to be used later on

# %%
df.plot(x="Name", y=["Attack", "Speed", "Defense","HP"],kind="bar") #Visualisation parameter is used as "strings" after the kind envelope
plt.show()  #example  figsize=(20,10)
#.area() .bar() .barh().box().hexbin().hist().kde().density().line().pie().scatter() Visualisation tools

# %%
df["Total"].mean() #Counting the mean of the total
# Out:
# 499.1666666666667

# %%
df[["HP", "Attack"]].median() #counting the median of HP and attack
# Out:
# HP        90.0
# Attack    75.0
# dtype: float64

# %%
df=df.drop(["Name", "Type 1","Type 2","Legendary"], axis=1) #Dropping the columns with no index values

# %%
sum_of_all_values=df[:].sum() #Counting the total of all values

# %%
number_of_pokemons=df.count()

# %%
print(sum_of_all_values/number_of_pokemons) #Another way to count the average of everything
# Out:
# #           94.666667
# Total      499.166667
# HP          84.166667
# Attack      85.416667
# Defense     96.916667
# Sp. Atk     78.333333
# Sp. Def     88.333333
# Speed       66.000000
# dtype: float64

# %%
df=(sum_of_all_values/number_of_pokemons)

# %%
df1.plot(x="Name", y=["Sp. Def","Sp. Atk"],kind="bar") #Special Attacks and defenses for every watertype pokemon
plt.show()

# %%
df.to_csv('Pokemon_remade.csv',index=False)
