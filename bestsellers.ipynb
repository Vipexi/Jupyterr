# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('bestsellers with categories.csv')
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
data=data.sort_values(by= ["User Rating"], ascending=False)

# %%
data
# Out:
#                                                   Name         Author  \
# 431                                 The Magnolia Story    Chip Gaines
# 87   Dog Man: Lord of the Fleas: From the Creator o...     Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...     Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...     Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...     Dav Pilkey
# ..                                                 ...            ...
# 22                                           Allegiant  Veronica Roth
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 132                         Go Set a Watchman: A Novel     Harper Lee
# 353                                 The Casual Vacancy   J.K. Rowling
#
#      User Rating  Reviews  Price  Year        Genre
# 431          4.9     7861      5  2016  Non Fiction
# ...

# %%
data=data.sort_values(by=["User Rating","Reviews"] , ascending=False)
data
# Out:
#                                                   Name         Author  \
# 252                          Oh, the Places You'll Go!      Dr. Seuss
# 251                          Oh, the Places You'll Go!      Dr. Seuss
# 249                          Oh, the Places You'll Go!      Dr. Seuss
# 250                          Oh, the Places You'll Go!      Dr. Seuss
# 245                          Oh, the Places You'll Go!      Dr. Seuss
# ..                                                 ...            ...
# 22                                           Allegiant  Veronica Roth
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 132                         Go Set a Watchman: A Novel     Harper Lee
# 353                                 The Casual Vacancy   J.K. Rowling
#
#      User Rating  Reviews  Price  Year    Genre
# 252          4.9    21834      8  2019  Fiction
# ...

# %%
#data.head()

# %%
#data=data.sort_values(by=["User Rating","Reviews"], ascending=False)
#data

# %%
#data = data.groupby("Genre")["Price"].mean() #  
#print(f'{data3[1] / data3[0] * 100 - 100:.2f}')

# %%
#data = data.groupby("Genre")["Price"].mean()

# %%
data[['Genre','Price']].groupby("Genre").mean()
# Out:
#                  Price
# Genre
# Fiction      10.850000
# Non Fiction  14.841935

# %%
print(14.841935/10.850000)
# Out:
# 1.3679202764976959

# %%
data1=data.groupby("Genre").mean() #data.drop_duplicates("Name", keep=False) removing names that comes again and again

# %%
data1
# Out:
#              User Rating       Reviews      Price         Year
# Genre
# Fiction         4.648333  15683.791667  10.850000  2013.925000
# Non Fiction     4.595161   9065.145161  14.841935  2014.058065

# %%
data_bestauthor= data.groupby("Author").mean()[["User Rating"]]
data_bestauthor.sort_values("User Rating",inplace=True, ascending=False)
data_bestauthor
# Out:
#                  User Rating
# Author
# Jill Twiss               4.9
# Nathan W. Pyle           4.9
# Chip Gaines              4.9
# Rush Limbaugh            4.9
# Bill Martin Jr.          4.9
# ...                      ...
# Paula Hawkins            4.1
# Muriel Barbery           4.0
# Gillian Flynn            4.0
# Gallup                   4.0
# Donna Tartt              3.9
#
# [248 rows x 1 columns]

# %%
"""most_books=data.loc[::,'Author'].value_counts().to_frame()
most_books.columns.values[0]= 'Name'
most_books.index.name='Author'
most_books.head(50)""" #Using valuecounts to get the 50 bestsellers
# Out:
#                                     Name
# Author
# Jeff Kinney                           12
# Suzanne Collins                       11
# Rick Riordan                          11
# Gary Chapman                          11
# American Psychological Association    10
# Gallup                                 9
# Dr. Seuss                              9
# Rob Elliott                            8
# Dav Pilkey                             7
# Stephenie Meyer                        7
# Eric Carle                             7
# Stephen R. Covey                       7
# Bill O'Reilly                          7
# The College Board                      6
# Harper Lee                             6
# Stieg Larsson                          6
# Don Miguel Ruiz                        6
# E L James                              6
# Sarah Young                            6
# J.K. Rowling                           6
# R. J. Palacio                          5
# Dale Carnegie                          5
# ...

# %%
#most_books=data.groupby("Author").count()

# %%
#most_books
# Out:
#                             Name  User Rating  Reviews  Price  Year  Genre
# Author
# Abraham Verghese               2            2        2      2     2      2
# Adam Gasiewski                 1            1        1      1     1      1
# Adam Mansbach                  1            1        1      1     1      1
# Adir Levy                      1            1        1      1     1      1
# Admiral William H. McRaven     1            1        1      1     1      1
# ...                          ...          ...      ...    ...   ...    ...
# Walter Isaacson                3            3        3      3     3      3
# William Davis                  2            2        2      2     2      2
# William P. Young               2            2        2      2     2      2
# Wizards RPG Team               3            3        3      3     3      3
# Zhi Gang Sha                   2            2        2      2     2      2
#
# [248 rows x 6 columns]

# %%
#most_books.sort_values("User Rating",inplace=True, ascending=False)

# %%
#most_books
# Out:
#                                     Name  User Rating  Reviews  Price  Year  \
# Author
# Jeff Kinney                           12           12       12     12    12
# Gary Chapman                          11           11       11     11    11
# Suzanne Collins                       11           11       11     11    11
# Rick Riordan                          11           11       11     11    11
# American Psychological Association    10           10       10     10    10
# ...                                  ...          ...      ...    ...   ...
# David Grann                            1            1        1      1     1
# Larry Schweikart                       1            1        1      1     1
# David McCullough                       1            1        1      1     1
# Khaled Hosseini                        1            1        1      1     1
# Muriel Barbery                         1            1        1      1     1
#
#                                     Genre
# ...

# %%
#most_books=most_books.iloc[0:51]

# %%
#most_books
# Out:
#                                     Name  User Rating  Reviews  Price  Year  \
# Author
# Jeff Kinney                           12           12       12     12    12
# Gary Chapman                          11           11       11     11    11
# Suzanne Collins                       11           11       11     11    11
# Rick Riordan                          11           11       11     11    11
# American Psychological Association    10           10       10     10    10
# Gallup                                 9            9        9      9     9
# Dr. Seuss                              9            9        9      9     9
# Rob Elliott                            8            8        8      8     8
# Eric Carle                             7            7        7      7     7
# Bill O'Reilly                          7            7        7      7     7
# Dav Pilkey                             7            7        7      7     7
# ...
