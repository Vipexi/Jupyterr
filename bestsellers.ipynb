# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('bestsellers with categories.csv')
data
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
data2=data.sort_values(by= ["User Rating"], ascending=False)

# %%
data2
# Out:
#                                                   Name         Author  \
# 431                                 The Magnolia Story    Chip Gaines
# 87   Dog Man: Lord of the Fleas: From the Creator o...     Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...     Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...     Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...     Dav Pilkey
# ..                                                 ...            ...
# 22                                           Allegiant  Veronica Roth
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 132                         Go Set a Watchman: A Novel     Harper Lee
# 353                                 The Casual Vacancy   J.K. Rowling
#
#      User Rating  Reviews  Price  Year        Genre
# 431          4.9     7861      5  2016  Non Fiction
# ...

# %%
data3=data2.sort_values(by=["User Rating","Reviews"] , ascending=False)

# %%
data3
# Out:
#                                                   Name         Author  \
# 252                          Oh, the Places You'll Go!      Dr. Seuss
# 251                          Oh, the Places You'll Go!      Dr. Seuss
# 249                          Oh, the Places You'll Go!      Dr. Seuss
# 250                          Oh, the Places You'll Go!      Dr. Seuss
# 245                          Oh, the Places You'll Go!      Dr. Seuss
# ..                                                 ...            ...
# 22                                           Allegiant  Veronica Roth
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 132                         Go Set a Watchman: A Novel     Harper Lee
# 353                                 The Casual Vacancy   J.K. Rowling
#
#      User Rating  Reviews  Price  Year    Genre
# 252          4.9    21834      8  2019  Fiction
# ...

# %%
data3 = data.groupby("Genre")["Price"].mean()
print(f'{data3[1] / data3[0] * 100 - 100:.2f}')
# Out:
# 36.79

# %%
data3 = data.groupby("Genre")["Price"].mean()

# %%
data3
# Out:
# Genre
# Fiction        10.850000
# Non Fiction    14.841935
# Name: Price, dtype: float64

# %%
data5=data.groupby("Genre").mean()

# %%
data5
# Out:
#              User Rating       Reviews      Price         Year
# Genre
# Fiction         4.648333  15683.791667  10.850000  2013.925000
# Non Fiction     4.595161   9065.145161  14.841935  2014.058065

# %%
data6=data.groupby("Author")["User Rating"].mean()

# %%
data10=data6.sort_values(ascending=False)

# %%
data10
# Out:
# Author
# Jill Twiss            4.9
# Bill Martin Jr.       4.9
# Nathan W. Pyle        4.9
# Patrick Thorpe        4.9
# Lin-Manuel Miranda    4.9
#                      ...
# Ian K. Smith M.D.     4.1
# Gallup                4.0
# Muriel Barbery        4.0
# Gillian Flynn         4.0
# Donna Tartt           3.9
# Name: User Rating, Length: 248, dtype: float64
