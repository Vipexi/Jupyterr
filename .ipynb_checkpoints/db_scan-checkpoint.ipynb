# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn import metrics
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('loisia.csv')
X = pd.read_csv('loisia.csv')

# %%
centers = [[1, 1]]

X, labels_true = make_blobs(n_samples=750, centers=centers, cluster_std=0.4,
                            random_state=0)

X = StandardScaler().fit_transform(X)

# Compute DBSCAN
db = DBSCAN(eps=0.3, min_samples=10).fit(X)
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

print('Estimated number of clusters: %d' % n_clusters_)
print('Estimated number of noise points: %d' % n_noise_)
print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels))
print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels))
print("V-measure: %0.3f" % metrics.v_measure_score(labels_true, labels))
print("Adjusted Rand Index: %0.3f"
      % metrics.adjusted_rand_score(labels_true, labels))
print("Adjusted Mutual Information: %0.3f"
      % metrics.adjusted_mutual_info_score(labels_true, labels))
print("Silhouette Coefficient: %0.3f"
      % metrics.silhouette_score(X, labels))

# Plot result
import matplotlib.pyplot as plt
# %matplotlib inline

# Black removed and is used for noise instead.
unique_labels = set(labels)
colors = [plt.cm.Spectral(each)
          for each in np.linspace(0, 1, len(unique_labels))]
for k, col in zip(unique_labels, colors):
    if k == -1:
        # Black used for noise.
        col = [0, 0, 0, 1]

    class_member_mask = (labels == k)

    xy = X[class_member_mask & core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'r', markerfacecolor=tuple(col),
             markeredgecolor='g', markersize=14)

    xy = X[class_member_mask & ~core_samples_mask]
    plt.plot(xy[:, 0], xy[:, 1], 'o', markerfacecolor=tuple(col),
             markeredgecolor='b', markersize=6)

plt.title('Estimated number of clusters: %d' % n_clusters_)
plt.show()
# Out:
# Estimated number of clusters: 2
# Estimated number of noise points: 111
# Homogeneity: 1.000
# Completeness: 0.000
# V-measure: 0.000
# Adjusted Rand Index: 0.000
# Adjusted Mutual Information: 0.000
# Silhouette Coefficient: 0.160

# %%
import pandas as pd
from sklearn.cluster import DBSCAN
import matplotlib.pyplot as plt

# %%
image, axes = plt.subplots (figsize = (15,12))
# Code explained:
# I know that the matplotlib library which I call "plt" contains the tool "subplots"
# could you use it to create an image and axes so that the image size is (15,12)

axes.scatter (df.y, df.x, s = 0.2)
# Code explained:
# could you plot the y and x values for all points on the image axes.
# I know I can assign colors for data points with parameter "c".
# Could you set colors based on a point cluster. Clusters can be found

axes.set_title ('parasites', fontsize = 20)
# Code explained:
# could you include the title 'PLAYER FEATURES' in the image so that the font size is 20

axes.set_ylabel ('y-axel', fontsize = 20)
axes.set_xlabel ('x-axel', fontsize = 20)
# Code explained:
# could you append the headings Property 1 and Property 2, in font size 20, to the x and y axes.

# axles.imshow (map, extent = mapBBox, aspect = 'auto')
# Code explained:
# Out:
# Text(0.5, 0, 'x-axel')

# %%
dbscan = DBSCAN (eps = 50, min_samples = 120).fit(df)
# Code - Savo:
# I would like to use the DBSCAN clustering tool in the SKLearn library and call it "dbscan"
# I would like to set the parameters eps to 0.001 and the MinPts to 40.
# NOTE !! : the MinPts value in SKLearn is called min_samples!

dbscan.fit(df)
# Code - Savo:
# could you now cluster "data"
# Out:
# DBSCAN(eps=50, min_samples=120)

# %%
image, axes = plt.subplots (figsize = (15,12))
# We went through this line of code before, try to explain it to yourself.

axes.scatter (df.y, df.x, c = dbscan.labels_, s = 0.2)
# Code explained:
# could you plot the y and x values for all points on the image axes.
# I know I can assign colors for data points with parameter "c".
# Could you set colors based on a point cluster. Clusters can be found



axes.set_title ('parasites', fontsize = 20)
# Code - Savo:
# could you include the title 'PLAYER FEATURES' in the image so that the font size is 20

axes.set_ylabel ('y-axel', fontsize = 20)
axes.set_xlabel ('x-axel', fontsize = 20)
# Code - Savo:
# could you append the headings Property 1 and Property 2, in font size 20, to the x and y axes.
# Out:
# Text(0.5, 0, 'x-axel')
