# %%
import numpy as np

# %%
import skimage

# %%
image = skimage.data.astronaut()
skimage.io.imshow(image)
skimage.io.show()

# %%
"""for i in range(4):
    image[100+i*50:150+i*50,100+i*25:125+i*25]=[0,0,255]
    image[100+i*50:150+i*50,250-i*25:275-i*25]=[0,0,255]"""
# Out:
# 'for i in range(4):\n    image[100+i*50:150+i*50,100+i*25:125+i*25]=[0,0,255]\n    image[100+i*50:150+i*50,250-i*25:275-i*25]=[0,0,255]'

# %%
face=image[20:21,12:14]=[240,0,0]
skimage.io.imshow(face)
skimage.io.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-dc7f90f5e9f4> in <module>
#       1 face=image[20:21,12:14]=[240,0,0]
# ----> 2 skimage.io.imshow(face)
#       3 skimage.io.show()
#
# ~/.local/lib/python3.8/site-packages/skimage/io/_io.py in imshow(arr, plugin, **plugin_args)
#     157     if isinstance(arr, str):
#     158         arr = call_plugin('imread', arr, plugin=plugin)
# --> 159     return call_plugin('imshow', arr, plugin=plugin, **plugin_args)
#     160
#     161
#
# ~/.local/lib/python3.8/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     207                                (plugin, kind))
#     208
# --> 209     return func(*args, **kwargs)
#     210
#     211
#
# ~/.local/lib/python3.8/site-packages/skimage/io/_plugins/matplotlib_plugin.py in imshow(image, ax, show_cbar, **kwargs)
# ...

# %%
face=image[20:180,150:300]
skimage.io.imshow(face)
skimage.io.show()

# %%
eye=face[70:90,35:60]
skimage.io.imshow(eye)
skimage.io.show()

# %%
red=eye[9:11,16:18]=[200,0,0]
skimage.io.imshow(eye)
skimage.io.show()

# %%
image[0:20,0:]=[0,0,200]
image[0:,0:20]=[0,0,200]
image[-20:,0:]=[0,0,200]
image[:,-20:]=[0,0,200]
skimage.io.imshow(image)
skimage.io.show()

# %%
image = skimage.data.astronaut()
skimage.io.imshow(image)
skimage.io.show()
