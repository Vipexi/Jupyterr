# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import graphviz

# %%
pd.set_option('display.max_columns', None)
df=pd.read_csv('Video_Games_Sales_as_at_22_Dec_2016.csv')

# %%
df.head(10)
# Out:
#                         Name Platform  Year_of_Release         Genre  \
# 0                 Wii Sports      Wii           2006.0        Sports
# 1          Super Mario Bros.      NES           1985.0      Platform
# 2             Mario Kart Wii      Wii           2008.0        Racing
# 3          Wii Sports Resort      Wii           2009.0        Sports
# 4   Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing
# 5                     Tetris       GB           1989.0        Puzzle
# 6      New Super Mario Bros.       DS           2006.0      Platform
# 7                   Wii Play      Wii           2006.0          Misc
# 8  New Super Mario Bros. Wii      Wii           2009.0      Platform
# 9                  Duck Hunt      NES           1984.0       Shooter
#
#   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  \
# 0  Nintendo     41.36     28.96      3.77         8.45         82.53
# ...

# %%
predictors = diab_data.drop(['Publisher'],axis=1) # Features

# %%
target = diab_data['Publisher'] # Target variable

# %%
#df.iloc[-1].Year_of_Release
# Out:
# 2016.0

# %%
#df.iloc[1000].Publisher
# Out:
# 'Take-Two Interactive'

# %%
#df.loc[5, "Publisher"]
# Out:
# 'Nintendo'

# %%
#df1=df.groupby("Platform")["Year_of_Release"].count()

# %%
#df1
# Out:
# Platform
# 2600     116
# 3DO        3
# 3DS      512
# DC        52
# DS      2122
# GB        97
# GBA      811
# GC       542
# GEN       29
# GG         1
# N64      316
# NES       98
# NG        12
# PC       957
# PCFX       1
# PS      1190
# PS2     2127
# PS3     1306
# PS4      393
# PSP     1193
# PSV      431
# SAT      173
# SCD        6
# SNES     239
# TG16       2
# WS         6
# Wii     1286
# WiiU     147
# X360    1232
# XB       803
# XOne     247
# Name: Year_of_Release, dtype: int64

# %%
#df.sort_values('Genre', ascending=True)
# Out:
#                                                   Name Platform  \
# 15879                                 Reine des Fleurs      PSV
# 15736                      Prototype: Biohazard Bundle      PS4
# 15735  Katekyoo Hitman Reborn! Kindan no Yami no Delta      PS2
# 15734                           Kimikare: New Semester      PSP
# 14104            Warhammer: The End Times - Vermintide      PS4
# ...                                                ...      ...
# 16076                                      Evil Genius       PC
# 16080                                 Imperium Romanum       PC
# 10685  Warhammer 40,000: Dawn of War II - Chaos Rising       PC
# 659                                                NaN      GEN
# 14246                                              NaN      GEN
#
#        Year_of_Release     Genre              Publisher  NA_Sales  EU_Sales  \
# 15879           2015.0    Action           Idea Factory      0.00      0.00
# ...
